# %%
# %matplotlib inline

import scipy.stats
import numpy as np
import matplotlib.pyplot as plt

# here we define a function that generates random data that has a normal distribution. 
# it then shows a line plot and histogram of the data
def plotNormalAndComputeConfidence(mean, std, num_samples):
    normal=np.random.normal(mean, std, num_samples)
    fig, ax = plt.subplots(1,2)
    fig.set_figwidth(15)
    fig.set_figheight(5)
    ax[0].plot(np.arange(num_samples), normal)
    ax[0].set_title(str(num_samples)+" random samples")
    ax[1].hist(normal,100)
    ax[1].set_title("Histogram of "+str(num_samples)+" samples.")
    print('confidence interval of data')
    print(scipy.stats.norm.interval(0.95, normal.mean(), normal.std()))
    print('confidence interval of mean')
    print(scipy.stats.t.interval(0.95, len(normal)-1, loc=np.mean(normal), scale=scipy.stats.sem(normal)))
    print()

# %%
help(scipy.stats.norm.interval)
# Out:
# Help on method interval in module scipy.stats._distn_infrastructure:
#
# interval(confidence, *args, **kwds) method of scipy.stats._continuous_distns.norm_gen instance
#     Confidence interval with equal areas around the median.
#
#     Parameters
#     ----------
#     confidence : array_like of float
#         Probability that an rv will be drawn from the returned range.
#         Each value should be in the range [0, 1].
#     arg1, arg2, ... : array_like
#         The shape parameter(s) for the distribution (see docstring of the
#         instance object for more information).
#     loc : array_like, optional
#         location parameter, Default is 0.
#     scale : array_like, optional
#         scale parameter, Default is 1.
#
#     Returns
#     -------
#     a, b : ndarray of float
#         end-points of range that contain ``100 * alpha %`` of the rv's
#         possible values.
#
#     Notes
#     -----
#     This is implemented as ``ppf([p_tail, 1-p_tail])``, where
# ...

# %%
mean=60
std=5
numsamples=10

plotNormalAndComputeConfidence(mean, std, 10)
plotNormalAndComputeConfidence(mean, std, 100)
plotNormalAndComputeConfidence(mean, std, 1000)
plotNormalAndComputeConfidence(mean, std, 10000)
plotNormalAndComputeConfidence(mean, std, 100000)
# Out:
# confidence interval of data
# (56.28849526016413, 73.67062019278032)
# confidence interval of mean
# (61.635865467317096, 68.32324998562734)
#
# confidence interval of data
# (49.04480886567677, 69.71193443892768)
# confidence interval of mean
# (58.32695815028232, 60.42978515432213)
#
# confidence interval of data
# (50.34686703644135, 70.14746660662615)
# confidence interval of mean
# (59.93355524175831, 60.56077840130919)
#
# confidence interval of data
# (50.23555502937667, 69.7923478941011)
# confidence interval of mean
# (59.91615076924023, 60.111752154237536)
#
# confidence interval of data
# (50.207305159592735, 69.801594095241)
# confidence interval of mean
# (59.97346780642851, 60.03543144840523)

# %%
help(plt.subplots)
# Out:
# Help on function subplots in module matplotlib.pyplot:
#
# subplots(nrows=1, ncols=1, sharex=False, sharey=False, squeeze=True, subplot_kw=None, gridspec_kw=None, **fig_kw)
#     Create a figure and a set of subplots.
#
#     This utility wrapper makes it convenient to create common layouts of
#     subplots, including the enclosing figure object, in a single call.
#
#     Parameters
#     ----------
#     nrows, ncols : int, optional, default: 1
#         Number of rows/columns of the subplot grid.
#
#     sharex, sharey : bool or {'none', 'all', 'row', 'col'}, default: False
#         Controls sharing of properties among x (`sharex`) or y (`sharey`)
#         axes:
#
#             - True or 'all': x- or y-axis will be shared among all
#               subplots.
#             - False or 'none': each subplot x- or y-axis will be
#               independent.
#             - 'row': each subplot row will share an x- or y-axis.
# ...
