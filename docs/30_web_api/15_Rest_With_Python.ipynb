# %% [markdown]
# ## Web API 2015
#
# Code example I gave in 2015

# %%
# first we need to import some modules
# utility to read json format
import json as js
# urllib2 is a module for fetching URL (Uniform Resource Locator) data
import urllib.request as ur
# import pandas
import pandas as pd

# %%
# following this example: http://stackoverflow.com/questions/13921910/python-urllib2-receive-json-response-from-url

request_string="http://maps.googleapis.com/maps/api/elevation/json?locations=42,73&sensor=false"    
response=ur.urlopen(request_string)
print(type(response))
data=js.load(response)
print(type(data))
# Out:
# <class 'http.client.HTTPResponse'>
# <class 'dict'>

# %%
request_string="http://api.fda.gov/drug/event.json?search=patient.drug.medicinalproduct:aspirin&count=patient.reaction.reactionmeddrapt.exact"
response=ur.urlopen(request_string)
data=js.load(response)
print(type(data))
print(data)
print(js.dumps(data, indent=4))
# Out:
# <class 'dict'>
# {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.', 'terms': 'https://open.fda.gov/terms/', 'license': 'https://open.fda.gov/license/', 'last_updated': '2023-08-02'}, 'results': [{'term': 'FATIGUE', 'count': 30724}, {'term': 'DYSPNOEA', 'count': 26403}, {'term': 'NAUSEA', 'count': 26332}, {'term': 'DIARRHOEA', 'count': 25253}, {'term': 'DIZZINESS', 'count': 22389}, {'term': 'DRUG INEFFECTIVE', 'count': 22006}, {'term': 'HEADACHE', 'count': 18963}, {'term': 'ASTHENIA', 'count': 18489}, {'term': 'FALL', 'count': 18141}, {'term': 'PAIN', 'count': 17920}, {'term': 'OFF LABEL USE', 'count': 16146}, {'term': 'MYOCARDIAL INFARCTION', 'count': 15281}, {'term': 'PNEUMONIA', 'count': 14969}, {'term': 'VOMITING', 'count': 14935}, {'term': 'DEATH', 'count': 14114}, {'term': 'GASTROINTESTINAL HAEMORRHAGE', 'count': 14034}, {'term': 'ARTHRALGIA', 'count': 13464}, {'term': 'MALAISE', 'count': 13272}, {'term': 'PAIN IN EXTREMITY', 'count': 13241}, {'term': 'PRURITUS', 'count': 13114}, {'term': 'WEIGHT DECREASED', 'count': 13008}, {'term': 'CHEST PAIN', 'count': 12102}, {'term': 'RASH', 'count': 11920}, {'term': 'ANAEMIA', 'count': 11900}, {'term': 'FLUSHING', 'count': 11746}, {'term': 'COUGH', 'count': 11239}, {'term': 'ACUTE KIDNEY INJURY', 'count': 11058}, {'term': 'HYPOTENSION', 'count': 11057}, {'term': 'CEREBROVASCULAR ACCIDENT', 'count': 10978}, {'term': 'CONSTIPATION', 'count': 10895}, {'term': 'BACK PAIN', 'count': 10503}, {'term': 'HYPERTENSION', 'count': 10479}, {'term': 'PYREXIA', 'count': 10380}, {'term': 'RENAL FAILURE', 'count': 9802}, {'term': 'INSOMNIA', 'count': 9665}, {'term': 'DECREASED APPETITE', 'count': 9651}, {'term': 'CHRONIC KIDNEY DISEASE', 'count': 9122}, {'term': 'ANXIETY', 'count': 9041}, {'term': 'CARDIAC FAILURE CONGESTIVE', 'count': 8400}, {'term': 'MUSCLE SPASMS', 'count': 8324}, {'term': 'GAIT DISTURBANCE', 'count': 8198}, {'term': 'ATRIAL FIBRILLATION', 'count': 8181}, {'term': 'URINARY TRACT INFECTION', 'count': 8070}, {'term': 'BLOOD GLUCOSE INCREASED', 'count': 8068}, {'term': 'ABDOMINAL PAIN', 'count': 7978}, {'term': 'FEELING ABNORMAL', 'count': 7978}, {'term': 'MYALGIA', 'count': 7905}, {'term': 'DRUG INTERACTION', 'count': 7787}, {'term': 'CONDITION AGGRAVATED', 'count': 7773}, {'term': 'ABDOMINAL PAIN UPPER', 'count': 7755}, {'term': 'DEPRESSION', 'count': 7747}, {'term': 'OEDEMA PERIPHERAL', 'count': 7737}, {'term': 'BLOOD PRESSURE INCREASED', 'count': 7582}, {'term': 'CONFUSIONAL STATE', 'count': 7504}, {'term': 'PARAESTHESIA', 'count': 7334}, {'term': 'HAEMOGLOBIN DECREASED', 'count': 7281}, {'term': 'DEHYDRATION', 'count': 7244}, {'term': 'WEIGHT INCREASED', 'count': 7135}, {'term': 'PERIPHERAL SWELLING', 'count': 6552}, {'term': 'CONTUSION', 'count': 6437}, {'term': 'SOMNOLENCE', 'count': 6401}, {'term': 'ABDOMINAL DISCOMFORT', 'count': 6165}, {'term': 'TREMOR', 'count': 6106}, {'term': 'HYPOAESTHESIA', 'count': 6081}, {'term': 'SYNCOPE', 'count': 6047}, {'term': 'DRUG HYPERSENSITIVITY', 'count': 6036}, {'term': 'ERYTHEMA', 'count': 6013}, {'term': 'HAEMORRHAGE', 'count': 5952}, {'term': 'MUSCULAR WEAKNESS', 'count': 5845}, {'term': 'CORONARY ARTERY DISEASE', 'count': 5682}, {'term': 'EPISTAXIS', 'count': 5666}, {'term': 'NASOPHARYNGITIS', 'count': 5639}, {'term': 'HYPERHIDROSIS', 'count': 5418}, {'term': 'LOSS OF CONSCIOUSNESS', 'count': 5299}, {'term': 'DRUG DOSE OMISSION', 'count': 5126}, {'term': 'GASTROOESOPHAGEAL REFLUX DISEASE', 'count': 5117}, {'term': 'MEMORY IMPAIRMENT', 'count': 4935}, {'term': 'NEUROPATHY PERIPHERAL', 'count': 4910}, {'term': 'VISION BLURRED', 'count': 4856}, {'term': 'DYSPEPSIA', 'count': 4752}, {'term': 'CHEST DISCOMFORT', 'count': 4703}, {'term': 'BALANCE DISORDER', 'count': 4646}, {'term': 'PALPITATIONS', 'count': 4634}, {'term ...
# {
#     "meta": {
#         "disclaimer": "Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.",
#         "terms": "https://open.fda.gov/terms/",
#         "license": "https://open.fda.gov/license/",
#         "last_updated": "2023-08-02"
#     },
#     "results": [
#         {
#             "term": "FATIGUE",
#             "count": 30724
#         },
#         {
#             "term": "DYSPNOEA",
#             "count": 26403
#         },
#         {
#             "term": "NAUSEA",
#             "count": 26332
#         },
#         {
#             "term": "DIARRHOEA",
#             "count": 25253
#         },
#         {
#             "term": "DIZZINESS",
#             "count": 22389
#         },
#         {
#             "term": "DRUG INEFFECTIVE",
#             "count": 22006
#         },
#         {
#             "term": "HEADACHE",
#             "count": 18963
#         },
#         {
#             "term": "ASTHENIA",
#             "count": 18489
#         },
#         {
#             "term": "FALL",
#             "count": 18141
#         },
#         {
#             "term": "PAIN",
#             "count": 17920
#         },
#         {
#             "term": "OFF LABEL USE",
#             "count": 16146
#         },
#         {
#             "term": "MYOCARDIAL INFARCTION",
#             "count": 15281
#         },
#         {
#             "term": "PNEUMONIA",
#             "count": 14969
#         },
#         {
#             "term": "VOMITING",
#             "count": 14935
#         },
#         {
#             "term": "DEATH",
#             "count": 14114
#         },
#         {
#             "term": "GASTROINTESTINAL HAEMORRHAGE",
#             "count": 14034
#         },
#         {
#             "term": "ARTHRALGIA",
#             "count": 13464
#         },
#         {
#             "term": "MALAISE",
#             "count": 13272
#         },
#         {
#             "term": "PAIN IN EXTREMITY",
#             "count": 13241
#         },
#         {
#             "term": "PRURITUS",
#             "count": 13114
#         },
#         {
#             "term": "WEIGHT DECREASED",
#             "count": 13008
#         },
#         {
#             "term": "CHEST PAIN",
#             "count": 12102
#         },
#         {
#             "term": "RASH",
#             "count": 11920
#         },
#         {
#             "term": "ANAEMIA",
#             "count": 11900
#         },
#         {
#             "term": "FLUSHING",
#             "count": 11746
#         },
#         {
#             "term": "COUGH",
#             "count": 11239
#         },
#         {
#             "term": "ACUTE KIDNEY INJURY",
#             "count": 11058
#         },
#         {
#             "term": "HYPOTENSION",
#             "count": 11057
#         },
#         {
#             "term": "CEREBROVASCULAR ACCIDENT",
#             "count": 10978
#         },
#         {
#             "term": "CONSTIPATION",
#             "count": 10895
#         },
#         {
#             "term": "BACK PAIN",
#             "count": 10503
#         },
#         {
#             "term": "HYPERTENSION",
#             "count": 10479
#         },
#         {
#             "term": "PYREXIA",
#             "count": 10380
#         },
#         {
#             "term": "RENAL FAILURE",
#             "count": 9802
#         },
#         {
#             "term": "INSOMNIA",
#             "count": 9665
#         },
#         {
#             "term": "DECREASED APPETITE",
#             "count": 9651
#         },
#         {
#             "term": "CHRONIC KIDNEY DISEASE",
#             "count": 9122
#         },
#         {
#             "term": "ANXIETY",
#             "count": 9041
#         },
#         {
#             "term": "CARDIAC FAILURE CONGESTIVE",
#             "count": 8400
#         },
#         {
#             "term": "MUSCLE SPASMS",
#             "count": 8324
#         },
#         {
#             "term": "GAIT DISTURBANCE",
#             "count": 8198
#         },
#         {
#             "term": "ATRIAL FIBRILLATION",
#             "count": 8181
#         },
#         {
#             "term": "URINARY TRACT INFECTION",
#             "count": 8070
#         },
#         {
#             "term": "BLOOD GLUCOSE INCREASED",
#             "count": 8068
#         },
#         {
#             "term": "ABDOMINAL PAIN",
#             "count": 7978
#         },
#         {
#             "term": "FEELING ABNORMAL",
#             "count": 7978
#         },
#         {
#             "term": "MYALGIA",
#             "count": 7905
#         },
#         {
#             "term": "DRUG INTERACTION",
#             "count": 7787
#         },
#         {
#             "term": "CONDITION AGGRAVATED",
#             "count": 7773
#         },
#         {
#             "term": "ABDOMINAL PAIN UPPER",
#             "count": 7755
#         },
#         {
#             "term": "DEPRESSION",
#             "count": 7747
#         },
#         {
#             "term": "OEDEMA PERIPHERAL",
#             "count": 7737
#         },
#         {
#             "term": "BLOOD PRESSURE INCREASED",
#             "count": 7582
#         },
#         {
#             "term": "CONFUSIONAL STATE",
#             "count": 7504
#         },
#         {
#             "term": "PARAESTHESIA",
#             "count": 7334
#         },
#         {
#             "term": "HAEMOGLOBIN DECREASED",
#             "count": 7281
#         },
#         {
#             "term": "DEHYDRATION",
#             "count": 7244
#         },
#         {
#             "term": "WEIGHT INCREASED",
#             "count": 7135
#         },
#         {
#             "term": "PERIPHERAL SWELLING",
#             "count": 6552
#         },
#         {
#             "term": "CONTUSION",
#             "count": 6437
#         },
#         {
#             "term": "SOMNOLENCE",
#             "count": 6401
#         },
#         {
#             "term": "ABDOMINAL DISCOMFORT",
#             "count": 6165
#         },
#         {
#             "term": "TREMOR",
#             "count": 6106
#         },
#         {
#             "term": "HYPOAESTHESIA",
#             "count": 6081
#         },
#         {
#             "term": "SYNCOPE",
#             "count": 6047
#         },
#         {
#             "term": "DRUG HYPERSENSITIVITY",
#             "count": 6036
#         },
#         {
#             "term": "ERYTHEMA",
#             "count": 6013
#         },
#         {
#             "term": "HAEMORRHAGE",
#             "count": 5952
#         },
#         {
#             "term": "MUSCULAR WEAKNESS",
#             "count": 5845
#         },
#         {
#             "term": "CORONARY ARTERY DISEASE",
#             "count": 5682
#         },
#         {
#             "term": "EPISTAXIS",
#             "count": 5666
#         },
#         {
#             "term": "NASOPHARYNGITIS",
#             "count": 5639
#         },
#         {
#             "term": "HYPERHIDROSIS",
#             "count": 5418
#         },
#         {
#             "term": "LOSS OF CONSCIOUSNESS",
#             "count": 5299
#         },
#         {
#             "term": "DRUG DOSE OMISSION",
#             "count": 5126
#         },
#         {
#             "term": "GASTROOESOPHAGEAL REFLUX DISEASE",
#             "count": 5117
#         },
#         {
#             "term": "MEMORY IMPAIRMENT",
#             "count": 4935
#         },
#         {
#             "term": "NEUROPATHY PERIPHERAL",
#             "count": 4910
#         },
#         {
#             "term": "VISION BLURRED",
#             "count": 4856
#         },
#         {
#             "term": "DYSPEPSIA",
#             "count": 4752
#         },
#         {
#             "term": "CHEST DISCOMFORT",
#             "count": 4703
#         },
#         {
#             "term": "BALANCE DISORDER",
#             "count": 4646
#         },
#         {
#             "term": "PALPITATIONS",
#             "count": 4634
#         },
#         {
#             "term": "ACUTE MYOCARDIAL INFARCTION",
#             "count": 4631
#         },
#         {
#             "term": "ALOPECIA",
#             "count": 4603
#         },
#         {
#             "term": "SEPSIS",
#             "count": 4556
#         },
#         {
#             "term": "PLATELET COUNT DECREASED",
#             "count": 4545
#         },
#         {
#             "term": "CARDIAC DISORDER",
#             "count": 4510
#         },
#         {
#             "term": "WHITE BLOOD CELL COUNT DECREASED",
#             "count": 4490
#         },
#         {
#             "term": "RENAL FAILURE ACUTE",
#             "count": 4481
#         },
#         {
#             "term": "CHILLS",
#             "count": 4271
#         },
#         {
#             "term": "THROMBOSIS",
#             "count": 4270
#         },
#         {
#             "term": "HYPERSENSITIVITY",
#             "count": 4263
#         },
#         {
#             "term": "FEELING HOT",
#             "count": 4194
#         },
#         {
#             "term": "CARDIAC FAILURE",
#             "count": 4183
#         },
#         {
#             "term": "JOINT SWELLING",
#             "count": 4171
#         },
#         {
#             "term": "THROMBOCYTOPENIA",
#             "count": 4165
#         },
#         {
#             "term": "GENERAL PHYSICAL HEALTH DETERIORATION",
#             "count": 4111
#         },
#         {
#             "term": "HEART RATE INCREASED",
#             "count": 4083
#         },
#         {
#             "term": "URTICARIA",
#             "count": 4060
#         }
#     ]
# }
